# %%
import sympy from libraries
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_18136/4008325078.py", line 1
#     import sympy from libraries
#                  ^
# SyntaxError: invalid syntax
