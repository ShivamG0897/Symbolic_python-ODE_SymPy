# %%
from sympy import * 
init_printing()
import numpy as np 
import matplotlib as plt
from ipywidgets import interactive
x,y,z,t,T = symbols(' x y z t T ')

# %%
from sympy.vector import *

# %%
pi
# Out:
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_png function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_rgba function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_mask function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# ...

# %%
1/7
# Out:
# 0.14285714285714285

# %%
S('1/7')
# Out:
# 1/7

# %%
# S is used as a Show fraction code #

# %%
import sympy as sym

# %%
pi.evalf(16)
# Out:
# 3.141592653589793

# %%
Eq1 = Eq( x*2 + 2 + 4*x**2)
Eq1
# Out:
# D:\Anaconda3\lib\site-packages\sympy\core\relational.py:495: SymPyDeprecationWarning:
#
# Eq(expr) with rhs default to 0 has been deprecated since SymPy 1.5.
# Use Eq(expr, 0) instead. See
# https://github.com/sympy/sympy/issues/16587 for more info.
#
#   SymPyDeprecationWarning(
#    2
# 4⋅x  + 2⋅x + 2 = 0

# %%
import matplotlib
matplotlib.get_backend()
# %matplotlib inline

# %%
S(pi/2)
# Out:
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_png function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_rgba function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_mask function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# D:\Anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# ...

# %%
plot(pi/2)

# %%
plot(3,0)

# %%
plot(10,10, 1)

# %%
plot(x,0,5)

# %%
hypo = Eq( y**2 , sqrt(5**2 + 5*x) )
hypo
# Out:
#  2     __________
# y  = ╲╱ 5⋅x + 25

# %%
val = solve( hypo, y )
val
# Out:
# ⎡ 4 __________  4 __________⎤
# ⎣-╲╱ 5⋅x + 25 , ╲╱ 5⋅x + 25 ⎦

# %%
plot(cos(2*x))

# %%
plot(tan(2*x) , cot(x) , 4*pi)

# %%
state1 = plot(cos(x) + sin(2*x))

# %%
Eq2 = plot(x**2 + 2*x - 3)

# %%
# check out latex form of mathematical equation on python 
#  eg plt.xlabel('$x$') - dollar sign here makes the label italic. similarly $/int$ - give the integral sign
